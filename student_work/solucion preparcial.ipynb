# %% [markdown]
# ##maxiomo y minomo, y numero de veces que sale es emaxio y minimo

# %%
def MinMax(L):
    if  len(L)==1:
        min=L[0]
        max=L[0]
        return min,max
    else:
        if MinMax(L[-1])> MinMax(L[-2]):

# %% [markdown]
# cuente el numero de picos en la lista L

# %%
def picos(L):
    if len(L)==3:
        if L[0]<L[1]>L[2]:
            return L[1] 
    else:
        if picos(L[:-1])<picos(L[:-2]) and picos(L[:-3])<picos(L[:-2]):
            
        else:

# %%
def picos(L):
    if len(L)<3:
        return 0
    pico=1 if L[0] < L[1] >L[2] else 0

# %%
def contar(S,S1,a):
